# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import KFold
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("data/abalone.csv")
data.head()
# Out:
#   Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0   M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1   M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2   F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3   M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4   I   0.330     0.255   0.080       0.2050         0.0895         0.0395
#
#    ShellWeight  Rings
# 0        0.150     15
# 1        0.070      7
# 2        0.210      9
# 3        0.155     10
# 4        0.055      7

# %%
data['Sex'] = data['Sex'].map(lambda x: 1 if x == 'M' else (-1 if x == 'F' else 0))
data.head()
# Out:
#    Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0    1   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1    1   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2   -1   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3    1   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4    0   0.330     0.255   0.080       0.2050         0.0895         0.0395
#
#    ShellWeight  Rings
# 0        0.150     15
# 1        0.070      7
# 2        0.210      9
# 3        0.155     10
# 4        0.055      7

# %%
X = data.ix[:, :-1]
y = data.ix[:, -1]

# %%
kfold = KFold(len(X), n_folds=5, shuffle=True, random_state=1)

def r2_scorer(estimator, X, y):
    predictions = estimator.predict(X)
    return r2_score(y, predictions)

for i in range(1, 50):
    clf = RandomForestRegressor(n_estimators=i, random_state=1)
    score = cross_val_score(clf, X, y, cv=kfold, scoring=r2_scorer)
    print("%s => %s => %s" % (i, score, sum(score) / len(score)))
# Out:
# 1 => [ 0.18870118  0.11762437  0.23292905  0.01941026 -0.04797139] => 0.102138694877
# 2 => [ 0.34846267  0.3125156   0.4051331   0.29357422  0.33239819] => 0.338416755158
# 3 => [ 0.43434817  0.3936471   0.44340066  0.34390711  0.4025962 ] => 0.403579849462
# 4 => [ 0.45447912  0.43027797  0.48305407  0.40143543  0.4443654 ] => 0.442722398967
# 5 => [ 0.46566914  0.4608503   0.49863336  0.42514138  0.46980965] => 0.464020766067
# 6 => [ 0.47019007  0.46473229  0.50030551  0.4408073   0.476873  ] => 0.470581632759
# 7 => [ 0.47222906  0.46260607  0.50658491  0.44950804  0.488225  ] => 0.475830616352
# 8 => [ 0.47745953  0.47097735  0.51752042  0.45392049  0.48883142] => 0.481741845626
# 9 => [ 0.48282964  0.47272102  0.52489282  0.46505661  0.49623898] => 0.488347813022
# 10 => [ 0.48250961  0.48147345  0.53536187  0.46746044  0.50551526] => 0.494464124802
# 11 => [ 0.48478914  0.47911134  0.53310796  0.47477633  0.495198  ] => 0.493396555
# 12 => [ 0.49406912  0.48202299  0.53239849  0.48302917  0.49830961] => 0.497965876398
# 13 => [ 0.49864214  0.48744587  0.53647303  0.4841015   0.50401976] => 0.502136460572
# 14 => [ 0.50570294  0.49077757  0.53850949  0.48685411  0.51029937] => 0.506428696226
# 15 => [ 0.50588972  0.49777492  0.54065454  0.48999717  0.50733964] => 0.508331197043
# 16 => [ 0.50451912  0.50108642  0.54372143  0.49368661  0.50955214] => 0.510513143832
# 17 => [ 0.50934964  0.50668554  0.54699345  0.49455223  0.51166061] => 0.513848294799
